# %%
import cv2
import numpy as np
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt

# Load CIFAR-10 dataset
(x_train, _), (_, _) = cifar10.load_data()

# Select 10 random images
images = x_train[:10]/255.0

# %%
filters = np.zeros((3, 3, 3, 2))
for i in range(3) :
  filters[i, i, :, 0] = 1
  filters[i, 2-i, :, 1] = 1

# %%
fig, axs = plt.subplots(1, 2)

axs[0].imshow(filters[:, :, :, 0])
axs[0].set_title('Filter 1')

axs[1].imshow(filters[:, :, :, 1])
axs[1].set_title('Filter 2')

plt.show()

# %%
convolved_images = tf.nn.conv2d(images, filters, strides=1, padding="SAME")

# %%
convolved_images.shape
# Out:
# TensorShape([10, 32, 32, 2])

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(images[0])
axs[0].set_title('original image 1')

axs[1].imshow(convolved_images[0,:,:,0])
axs[1].set_title('Filter 1')

axs[2].imshow(convolved_images[0,:,:,1])
axs[2].set_title('Filter 2')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(images[1])
axs[0].set_title('original image 2')

axs[1].imshow(convolved_images[1,:,:,0])
axs[1].set_title('Filter 1')

axs[2].imshow(convolved_images[1,:,:,1])
axs[2].set_title('Filter 2')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(images[2])
axs[0].set_title('original image 3')

axs[1].imshow(convolved_images[2,:,:,0])
axs[1].set_title('Filter 1')

axs[2].imshow(convolved_images[2,:,:,1])
axs[2].set_title('Filter 2')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(images[3])
axs[0].set_title('original image 4')

axs[1].imshow(convolved_images[3,:,:,0])
axs[1].set_title('Filter 1')

axs[2].imshow(convolved_images[3,:,:,1])
axs[2].set_title('Filter 2')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(images[4])
axs[0].set_title('original image 5')

axs[1].imshow(convolved_images[4,:,:,0])
axs[1].set_title('Filter 1')

axs[2].imshow(convolved_images[4,:,:,1])
axs[2].set_title('Filter 2')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(images[5])
axs[0].set_title('original image 6')

axs[1].imshow(convolved_images[5,:,:,0])
axs[1].set_title('Filter 1')

axs[2].imshow(convolved_images[5,:,:,1])
axs[2].set_title('Filter 2')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(images[6])
axs[0].set_title('original image 7')

axs[1].imshow(convolved_images[6,:,:,0])
axs[1].set_title('Filter 1')

axs[2].imshow(convolved_images[6,:,:,1])
axs[2].set_title('Filter 2')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(images[7])
axs[0].set_title('original image 8')

axs[1].imshow(convolved_images[7,:,:,0])
axs[1].set_title('Filter 1')

axs[2].imshow(convolved_images[7,:,:,1])
axs[2].set_title('Filter 2')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(images[8])
axs[0].set_title('original image 9')

axs[1].imshow(convolved_images[8,:,:,0])
axs[1].set_title('Filter 1')

axs[2].imshow(convolved_images[8,:,:,1])
axs[2].set_title('Filter 2')

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(images[9])
axs[0].set_title('original image 10')

axs[1].imshow(convolved_images[9,:,:,0])
axs[1].set_title('Filter 1')

axs[2].imshow(convolved_images[9,:,:,1])
axs[2].set_title('Filter 2')

plt.show()
